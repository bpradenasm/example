884259760016133, -2.386554182640294, -0.2882211210894664, -0.42544341393508367, -1.6840814613465283, 1.5071363545327314, 0.16465071236681542, -0.6494204517214924, 0.10648363409320222, 0.31545919016844853, 1.0615342329056383, 0.8659440301678824, -0.010299880272361084, 0.12315625077918618, -0.5271156285998985, 1.8028909970976603, -0.04796263448829776, 0.15889364266178832, 1.075393846285602, 0.021244569894735804, -2.465142202805984, 0.3843990611343847, -1.5839068350215872, 0.33257832435218704, -0.21369915311957274, 0.2878014528593373, -0.6018468476221921, 0.45880253292238526, 1.6046908098868466, -0.08266216196478218, -1.3163715295985685, 1.5013769617979686, 0.3456899642217961, -0.46959682786182577, 1.1170327638025328, 1.08351053204 ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import networkx as nx

G=nx.random_geometric_graph(200,0.125)
pos=nx.get_node_attributes(G,'pos')

dmin=1
ncenter=0
for n in pos:
    x,y=pos[n]
    d=(x-0.5)**2+(y-0.5)**2
    if d<dmin:
        ncenter=n
        dmin=d

p=nx.single_source_shortest_path_length(G,ncenter)

# %%
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=0.5,color='#888'),
    hoverinfo='none',
    mode='lines')

for edge in G.edges():
    x0, y0 = G.node[edge[0]]['pos']
    x1, y1 = G.node[edge[1]]['pos']
    edge_trace['x'] += tuple([x0, x1, None])
    edge_trace['y'] += tuple([y0, y1, None])

node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line=dict(width=2)))

for node in G.nodes():
    x, y = G.node[node]['pos']
    node_trace['x'] += tuple([x])
    node_trace['y'] += tuple([y])

# %%
for node, adjacencies in enumerate(G.adjacency()):
    node_trace['marker']['color']+=tuple([len(adjacencies[1])])
    node_info = '# of connections: '+str(len(adjacencies[1]))
    node_trace['text']+=tuple([node_info])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-76a2e6df2f16> in <module>()
# ----> 1 for node, adjacencies in enumerate(G.adjacency()):
#       2     node_trace['marker']['color']+=tuple([len(adjacencies[1])])
#       3     node_info = '# of connections: '+str(len(adjacencies[1]))
#       4     node_trace['text']+=tuple([node_info])
#
# AttributeError: 'Graph' object has no attribute 'adjacency'

# %%
fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                title='<br>Network graph made with Python',
                titlefont=dict(size=16),
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                annotations=[ dict(
                    text="Python code: <a href='https://plot.ly/ipython-notebooks/network-graphs/'> https://plot.ly/ipython-notebooks/network-graphs/</a>",
                    showarrow=False,
                    xref="paper", yref="paper",
                    x=0.005, y=-0.002 ) ],
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

py.offline.iplot(fig, filename='networkx')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-154ad6448e27> in <module>()
#      14                 yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))
#      15
# ---> 16 py.iplot(fig, filename='networkx')
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     150             layout = layout.to_plotly_json()
#     151     elif isinstance(figure_or_data, BaseFigure):
# --> 152         layout = figure_or_data.layout.to_plotly_json()
#     153     else:
#     154         layout = {}
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     239     fig = tools._replace_newline(figure)  # does not mutate figure
#     240     data = fig.get('data', [])
# --> 241     plot_options['layout'] = fig.get('layout', {})
#     242     response = v1.clientresp(data, **plot_options)
#     243
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/plotly/plotly/plotly.pyc in _send_to_plotly(figure, **plot_options)
#    1431     my_dboard.insert(box_2, 'above', 1)
#    1432     # my_dboard.get_preview()
# -> 1433
#    1434     py.dashboard_ops.upload(my_dboard)
#    1435     ```
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/requests/api.pyc in post(url, data, json, **kwargs)
#     108     :return: :class:`Response <Response>` object
#     109     :rtype: requests.Response
# --> 110     """
#     111
#     112     return request('post', url, data=data, json=json, **kwargs)
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # By using the 'with' statement we are sure the session is closed, thus we
#      55     # avoid leaving sockets open which can trigger a ResourceWarning in some
# ---> 56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
#      58         return session.request(method=method, url=url, **kwargs)
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     472         :param allow_redirects: (optional) Set to True by default.
#     473         :type allow_redirects: bool
# --> 474         :param proxies: (optional) Dictionary mapping protocol or protocol and
#     475             hostname to the URL of the proxy.
#     476         :param stream: (optional) whether to immediately download the response
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in prepare_request(self, request)
#     405     def prepare_request(self, request):
#     406         """Constructs a :class:`PreparedRequest <PreparedRequest>` for
# --> 407         transmission and returns it. The :class:`PreparedRequest` has settings
#     408         merged from the :class:`Request <Request>` instance and those of the
#     409         :class:`Session`.
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/requests/models.pyc in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     300         #: integer denoting starting position of a readable file-like body.
#     301         self._body_position = None
# --> 302
#     303     def prepare(self,
#     304             method=None, url=None, headers=None, files=None, data=None,
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/requests/models.pyc in prepare_url(self, url, params)
#     376         except LocationParseError as e:
#     377             raise InvalidURL(*e.args)
# --> 378
#     379         if not scheme:
#     380             error = ("Invalid URL {0!r}: No schema supplied. Perhaps you meant http://{0}?")
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/requests/packages/idna/core.pyc in encode(s, strict, uts46, std3_rules, transitional)
#
# /Users/macbook/anaconda/lib/python2.7/site-packages/requests/packages/idna/core.pyc in uts46_remap(domain, std3_rules, transitional)
#
# ImportError: No module named uts46data
